# %%
import pandas as pd

# %%
results = pd.read_csv("results.csv")

# %%
results.rename(columns=lambda x: x.strip(), inplace=True)

# %%
results
# Out:
#     epoch  train/box_loss  train/obj_loss  train/cls_loss  metrics/precision  \
# 0       0        0.029109        0.009922               0           0.007277
# 1       1        0.022371        0.006099               0           0.014501
# 2       2        0.018207        0.004700               0           0.080422
# 3       3        0.015220        0.003835               0           0.365820
# 4       4        0.013946        0.003429               0           0.366830
# 5       5        0.012957        0.003208               0           0.514240
# 6       6        0.011893        0.003088               0           0.564350
# 7       7        0.009917        0.002943               0           0.479080
# 8       8        0.010603        0.002880               0           0.651460
# 9       9        0.010006        0.002817               0           0.696460
# 10     10        0.010085        0.002688               0           0.635460
# ...

# %%
results["best"] =   0.10*results["metrics/precision"] +\
                    0.50*results["metrics/recall"] +\
                    0.20*results["metrics/mAP_0.5"] +\
                    0.20*results["metrics/mAP_0.5:0.95"]

# %%
results.sort_values(by=['best'])
# Out:
#     epoch  train/box_loss  train/obj_loss  train/cls_loss  metrics/precision  \
# 0       0        0.029109        0.009922               0           0.007277
# 1       1        0.022371        0.006099               0           0.014501
# 2       2        0.018207        0.004700               0           0.080422
# 3       3        0.015220        0.003835               0           0.365820
# 4       4        0.013946        0.003429               0           0.366830
# 5       5        0.012957        0.003208               0           0.514240
# 14     14        0.009243        0.002326               0           0.623150
# 10     10        0.010085        0.002688               0           0.635460
# 6       6        0.011893        0.003088               0           0.564350
# 7       7        0.009917        0.002943               0           0.479080
# 12     12        0.010085        0.002538               0           0.793510
# ...

# %%
results[results["best"].max() == results['best']]
# Out:
#     epoch  train/box_loss  train/obj_loss  train/cls_loss  metrics/precision  \
# 29     29        0.007033        0.001803               0            0.89438
#
#     metrics/recall  metrics/mAP_0.5  metrics/mAP_0.5:0.95  val/box_loss  \
# 29         0.82258          0.87178                0.4872      0.016329
#
#     val/obj_loss  val/cls_loss     x/lr0     x/lr1     x/lr2      best
# 29      0.001567             0  0.000209  0.000209  0.000209  0.772524
